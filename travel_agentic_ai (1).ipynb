# %%
{
 "cells": [
  {
   "cell_type": "code",
   "source": [
    "# \ud83e\udded AI Travel Planner Agent\n",
    "# \ud83d\udcc5 IBM SkillsBuild Internship Project\n",
    "# \ud83d\udc69\u200d\ud83d\udcbb Developed by: KEERTHI\n",
    "# \ud83c\udfeb College: KL UNIVERSITY, Department of CSE\n",
    "# \ud83d\udca1 Objective: To build a simple AI-powered chatbot that helps users with travel-related questions using Python and a predefined knowledge base."
   ],
   "metadata": {},
   "execution_count": None,
   "outputs": []
  },
  {
   "cell_type": "code",
   "source": [
    "!pip install googletrans==4.0.0-rc1"
   ],
   "metadata": {},
   "execution_count": None,
   "outputs": []
  },
  {
   "cell_type": "code",
   "source": [
    "import json\n",
    "from IPython.display import display, Markdown\n",
    "\n",
    "# \ud83d\udde3\ufe0f For translation (optional)\n",
    "try:\n",
    "    from googletrans import Translator\n",
    "except:\n",
    "    Translator = None"
   ],
   "metadata": {},
   "execution_count": None,
   "outputs": []
  },
  {
   "cell_type": "code",
   "source": [
    "# \ud83d\udcda Predefined Q&A for travel-related questions\n",
    "knowledge_base = [\n",
    "    {\n",
    "        \"question\": \"suggest a place in india\",\n",
    "        \"answer\": \"\ud83c\uddee\ud83c\uddf3 You can explore places like Jaipur for royal heritage, Kerala for backwaters, or Manali for snow-capped adventures.\"\n",
    "    },\n",
    "    {\n",
    "        \"question\": \"best time to visit goa\",\n",
    "        \"answer\": \"\ud83c\udf1e The best time to visit Goa is from November to February when the weather is pleasant and perfect for beaches.\"\n",
    "    },\n",
    "    {\n",
    "        \"question\": \"recommend hotels in delhi\",\n",
    "        \"answer\": \"\ud83c\udfe8 Top hotels in Delhi include The Imperial, Taj Palace, and ITC Maurya. Booking.com or MakeMyTrip can help you compare options.\"\n",
    "    },\n",
    "    {\n",
    "        \"question\": \"how to travel from chennai to pondicherry\",\n",
    "        \"answer\": \"\ud83d\ude8c You can travel by road via ECR (East Coast Road), which is scenic. Buses, taxis, or even self-drive options are available.\"\n",
    "    },\n",
    "    {\n",
    "        \"question\": \"suggest travel essentials\",\n",
    "        \"answer\": \"\ud83e\uddf3 Pack light clothes, toiletries, a power bank, identity proof, and always keep a water bottle handy!\"\n",
    "    }\n",
    "]"
   ],
   "metadata": {},
   "execution_count": None,
   "outputs": []
  },
  {
   "cell_type": "code",
   "source": [
    "# \ud83d\udd0d Function to find a matching answer from the knowledge base\n",
    "def get_answer(user_input):\n",
    "    for item in knowledge_base:\n",
    "        if user_input.lower() in item['question'].lower():\n",
    "            return item['answer']\n",
    "    return \"\ud83e\udd16 Sorry, I don't have information on that. Try rephrasing or be more specific!\""
   ],
   "metadata": {},
   "execution_count": None,
   "outputs": []
  },
  {
   "cell_type": "code",
   "source": [
    "# \ud83c\udf10 Function to translate responses to another language (e.g., Tamil, Hindi)\n",
    "def translate_to_language(text, lang='ta'):\n",
    "    if Translator:\n",
    "        translator = Translator()\n",
    "        translated = translator.translate(text, dest=lang)\n",
    "        return translated.text\n",
    "    else:\n",
    "        return \"(Translation unavailable \u2013 googletrans not installed)\""
   ],
   "metadata": {},
   "execution_count": None,
   "outputs": []
  },
  {
   "cell_type": "code",
   "source": [
    "# \ud83d\udcac Simple chat interface inside Jupyter Notebook\n",
    "def chat():\n",
    "    print(\"\ud83e\udded Welcome to the AI Travel Planner Agent\")\n",
    "    print(\"\ud83d\udcac Ask your travel-related question below\")\n",
    "    print(\"\ud83d\udd1a Type 'exit' to end the chat.\\n\")\n",
    "    \n",
    "    while True:\n",
    "        user_input = input(\"You: \")\n",
    "        if user_input.lower() == \"exit\":\n",
    "            print(\"Agent: Have a great trip! \u2708\ufe0f\ud83c\udf0d\")\n",
    "            break\n",
    "        answer = get_answer(user_input)\n",
    "        print(\"Agent:\", answer)"
   ],
   "metadata": {},
   "execution_count": None,
   "outputs": []
  },
  {
   "cell_type": "code",
   "source": [
    "# \u25b6\ufe0f Start the chatbot\n",
    "chat()"
   ],
   "metadata": {},
   "execution_count": None,
   "outputs": []
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python [conda env:base] *",
   "language": "python",
   "name": "conda-base-py"
  },
  "language_info": {
   "name": "python",
   "version": "3.12.7",
   "file_extension": ".py"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
# Out:
# {'cells': [{'cell_type': 'code',
#    'source': ['# \ud83e\udded AI Travel Planner Agent\n',
#     '# \ud83d\udcc5 IBM SkillsBuild Internship Project\n',
#     '# \ud83d\udc69\u200d\ud83d\udcbb Developed by: KEERTHI\n',
#     '# \ud83c\udfeb College: KL UNIVERSITY, Department of CSE\n',
#     '# \ud83d\udca1 Objective: To build a simple AI-powered chatbot that helps users with travel-related questions using Python and a predefined knowledge base.'],
#    'metadata': {},
#    'execution_count': None,
#    'outputs': []},
#   {'cell_type': 'code',
#    'source': ['!pip install googletrans==4.0.0-rc1'],
#    'metadata': {},
#    'execution_count': None,
#    'outputs': []},
#   {'cell_type': 'code',
#    'source': ['import json\n',
#     'from IPython.display import display, Markdown\n',
#     '\n',
#     '# \ud83d\udde3️ For translation (optional)\n',
#     'try:\n',
#     '    from googletrans import Translator\n',
#     'except:\n',
#     '    Translator = None'],
# ...
